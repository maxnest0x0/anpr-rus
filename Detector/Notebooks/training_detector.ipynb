# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.9/906.9 kB 14.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from ultralytics import YOLO
model = YOLO('/kaggle/input/ssssss/best.pt')

results = model.train(data='/kaggle/input/dataset8/data.yaml', epochs=70, imgsz=640, model='yolov8m.pt')
# Out:
# Ultralytics 8.3.60 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')


results = model.train(data='/kaggle/input/dataset4/data.yaml', epochs=100, imgsz=640, model='yolov8m.pt')
# Out:
# Ultralytics 8.3.56 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...
